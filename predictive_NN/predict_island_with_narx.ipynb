# %% [markdown]
# # Setup

# %%
# !pip install scikit-learn
# !pip install numpy
# !pip install scipy
# !pip install sysidentpy
# !pip install matplotlib==3.1.3
# !pip install catboost
# Out:
# Requirement already satisfied: scikit-learn in c:\users\walte\.conda\envs\ml\lib\site-packages (1.2.0)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\walte\.conda\envs\ml\lib\site-packages (from scikit-learn) (1.22.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\walte\.conda\envs\ml\lib\site-packages (from scikit-learn) (3.1.0)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\walte\.conda\envs\ml\lib\site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\walte\.conda\envs\ml\lib\site-packages (from scikit-learn) (1.7.0)
# ^C
# Requirement already satisfied: numpy in c:\users\walte\.conda\envs\ml\lib\site-packages (1.22.4)
# Requirement already satisfied: scipy in c:\users\walte\.conda\envs\ml\lib\site-packages (1.7.0)
# Requirement already satisfied: numpy<1.23.0,>=1.16.5 in c:\users\walte\.conda\envs\ml\lib\site-packages (from scipy) (1.22.4)
# Requirement already satisfied: sysidentpy in c:\users\walte\.conda\envs\ml\lib\site-packages (0.2.1)
# Requirement already satisfied: matplotlib>=3.3.2 in c:\users\walte\.conda\envs\ml\lib\site-packages (from sysidentpy) (3.6.2)
# Requirement already satisfied: numpy>=1.19.2 in c:\users\walte\.conda\envs\ml\lib\site-packages (from sysidentpy) (1.22.4)
# Requirement already satisfied: scipy>=1.7.0 in c:\users\walte\.conda\envs\ml\lib\site-packages (from sysidentpy) (1.7.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\walte\.conda\envs\ml\lib\site-packages (from matplotlib>=3.3.2->sysidentpy) (4.38.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\walte\.conda\envs\ml\lib\site-packages (from matplotlib>=3.3.2->sysidentpy) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in c:\users\walte\.conda\envs\ml\lib\site-packages (from matplotlib>=3.3.2->sysidentpy) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\walte\.conda\envs\ml\lib\site-packages (from matplotlib>=3.3.2->sysidentpy) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\walte\.conda\envs\ml\lib\site-packages (from matplotlib>=3.3.2->sysidentpy) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\walte\.conda\envs\ml\lib\site-packages (from matplotlib>=3.3.2->sysidentpy) (21.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\walte\.conda\envs\ml\lib\site-packages (from matplotlib>=3.3.2->sysidentpy) (1.0.6)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\walte\.conda\envs\ml\lib\site-packages (from matplotlib>=3.3.2->sysidentpy) (9.4.0)
# Requirement already satisfied: six>=1.5 in c:\users\walte\.conda\envs\ml\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.2->sysidentpy) (1.16.0)

# %% [markdown]
# https://sysidentpy.org/

# %% [markdown]
# # NARX with exogenous inputs

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sysidentpy.model_structure_selection import FROLS
from sysidentpy.basis_function import Polynomial, Fourier
from sysidentpy.metrics import root_relative_squared_error
from sysidentpy.utils.generate_data import get_siso_data,get_miso_data
from sysidentpy.utils.display_results import results
from sysidentpy.utils.plotting import plot_residues_correlation, plot_results
from sysidentpy.residues.residues_correlation import compute_residues_autocorrelation, compute_cross_correlation

from sklearn.model_selection import TimeSeriesSplit

# %%
d34 = scipy.io.loadmat('/content/drive/MyDrive/MIT/turbulence/pset3/data_pset3/Data_34.mat',simplify_cells=True)

# %% [markdown]
# Set up the training and testing data

# %%
xl = []
yl = []
for i in range(len(d34["u2"])):
  xl.append([d34["u2"][i],d34["v2"][i]])#,d34["w2"][i]])
  yl.append(d34["v2"][i])

x = np.array(xl)
y = np.array([yl])
y=y.transpose()

# Add in a 2 period gap
tscv = TimeSeriesSplit(n_splits=2, test_size=50, gap=10)
for train_index, test_index in tscv.split(x):
  # print("TRAIN:", train_index, "TEST:", test_index)
  x_train, x_valid = x[train_index], x[test_index]
  y_train, y_valid = y[train_index], y[test_index]


print(x_train.shape); print(x_valid.shape);print(y_train.shape); print(y_valid.shape)
# Out:
# (5367, 2)
# (50, 2)
# (5367, 1)
# (50, 1)

# %%
basis_function = Polynomial(degree=2)

model = FROLS(
    order_selection=True,
    n_terms=4,
    extended_least_squares=False,
    ylag=2, xlag=[[1,2],[1,2]],
    info_criteria='aic',
    estimator='least_squares',
    basis_function=basis_function
)

# %%
model.fit(X=x_train, y=y_train)

# %%
#predicting 10 time steps ahead
yhat = model.predict(X=x_valid, y=y_valid,steps_ahead=10)
rrse = root_relative_squared_error(y_valid, yhat)
print(rrse)

r = pd.DataFrame(
    results(
        model.final_model, model.theta, model.err,
        model.n_terms, err_precision=8, dtype='sci'
        ),
    columns=['Regressors', 'Parameters', 'ERR'])
print(r)
plot_results(y=y_valid, yhat = yhat, n=1000)
ee = compute_residues_autocorrelation(y_valid, yhat)
# plot_residues_correlation(data=ee, title="Residues", ylabel="$e^2$")
# x1e = compute_cross_correlation(y_valid, yhat, x_valid[:, 0])
# plot_residues_correlation(data=x1e, title="Residues", ylabel="$x_1e$")
# Out:
# 0.9465133106629052
#   Regressors   Parameters             ERR
# 0     y(k-1)   1.3314E+00  9.43587621E-01
# 1   y(k-2)^2  -3.5902E-02  1.03038148E-02
# 2     y(k-2)  -3.8027E-01  2.64020724E-03
# 3    x1(k-2)   9.7328E-02  1.48775507E-03

# %%
#predicting 1 timestep ahead (much easier for network)
yhat = model.predict(X=x_valid, y=y_valid,steps_ahead=1)
rrse = root_relative_squared_error(y_valid, yhat)
print(rrse)

r = pd.DataFrame(
    results(
        model.final_model, model.theta, model.err,
        model.n_terms, err_precision=8, dtype='sci'
        ),
    columns=['Regressors', 'Parameters', 'ERR'])
print(r)
plot_results(y=y_valid, yhat = yhat, n=1000)
ee = compute_residues_autocorrelation(y_valid, yhat)
# plot_residues_correlation(data=ee, title="Residues", ylabel="$e^2$")
# x1e = compute_cross_correlation(y_valid, yhat, x_valid[:, 0])
# plot_residues_correlation(data=x1e, title="Residues", ylabel="$x_1e$")
# Out:
# 0.3614951069007878
#   Regressors   Parameters             ERR
# 0     y(k-1)   1.3314E+00  9.43587621E-01
# 1   y(k-2)^2  -3.5902E-02  1.03038148E-02
# 2     y(k-2)  -3.8027E-01  2.64020724E-03
# 3    x1(k-2)   9.7328E-02  1.48775507E-03
